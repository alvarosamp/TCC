# %%
from obspy.clients.fdsn import Client

client = Client("SCEDC")

# Substitua pela sua estação (ex: CI, PAS, etc.)
inv = client.get_stations(network="CI", station="PAS", level="response")
inv.write("estacao_PAS.xml", format="STATIONXML")
print(inv)
# Out:
# Inventory created at 2026-02-27T21:15:27.000000Z
# 	Created by: SCEDC WEB SERVICE: fdsnws-station | version: 1.1
# 		    http://service.scedc.caltech.edu/fdsnws/station/1/query?net=CI&sta=...
# 	Sending institution: SCEDC (SCEDC)
# 	Contains:
# 		Networks (1):
# 			CI
# 		Stations (1):
# 			CI.PAS (Pasadena)
# 		Channels (151):
# 			CI.PAS..BHZ (7x), CI.PAS..BHN (7x), CI.PAS..BHE (7x), CI.PAS..BLZ,
# 			CI.PAS..BLN, CI.PAS..BLE, CI.PAS..EHZ (3x), CI.PAS..EHN,
# 			CI.PAS..EHE, CI.PAS..ELZ, CI.PAS..ELN, CI.PAS..ELE,
# 			CI.PAS..HDI (3x), CI.PAS..HDO (3x), CI.PAS..HHZ (5x),
# 			CI.PAS..HHN (5x), CI.PAS..HHE (5x), CI.PAS..HLZ (7x),
# 			CI.PAS..HLN (7x), CI.PAS..HLE (7x), CI.PAS..LDI (4x),
# 			CI.PAS..LDO (4x), CI.PAS..LHZ (7x), CI.PAS..LHN (7x),
# 			CI.PAS..LHE (7x), CI.PAS..LLZ (7x), CI.PAS..LLN (7x),
# 			CI.PAS..LLE (7x), CI.PAS..VHZ (6x), CI.PAS..VHN (6x),
# 			CI.PAS..VHE (6x), CI.PAS..VMZ (3x), CI.PAS..VMN (3x),
# 			CI.PAS..VME (3x)
